# %%
import numpy as np
import pandas as pd
import glob

# %%
wods = pd.read_csv('../observations/sugarwod/workouts.csv')

# %%
wods.head()
# Out:
#          date                  title  \
# 0  02/10/2022                 021022
# 1  03/07/2022     For Time Intervals
# 2  03/14/2022                 220314
# 3  03/15/2022                 220315
# 4  03/18/2022  Conditioning For Time
#
#                                          description  best_result_raw  \
# 0  5 Rounds:15 Swings (70/53)15 BurpeeGoal: Sub 1...            576.0
# 1  For Time:3 Rounds20 Wall Ball (20/14#)20 Kettl...           1046.0
# 2  - RX -5 rounds for time:15 strict handstand pu...           1916.0
# 3  - RX -AMRAP 21: Run 400/200/100  -OR- Bike 100...             60.0
# 4  For Time:800 Meter Run or 2000/1600m bikeREST ...            878.0
#
#   best_result_display score_type barbell_lift              set_details  \
# 0                9:36       Time          NaN   [{"secs":36,"mins":9}]
# 1               17:26       Time          NaN  [{"secs":26,"mins":17}]
# 2               31:56       Time          NaN  [{"secs":56,"mins":31}]
# ...

# %%
wods.info()

# %%
wods.describe()
