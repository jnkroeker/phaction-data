# %%
# %run -i '../extract_apple_health_data' '../export.xml'
# Out:
# Reading data from ../export.xml . . . done
# Unexpected node of type ExportDate.
#
# Tags:
# ActivitySummary: 961
# ExportDate: 1
# Me: 1
# Record: 2378223
# Workout: 128
#
# Fields:
# HKCharacteristicTypeIdentifierBiologicalSex: 1
# HKCharacteristicTypeIdentifierBloodType: 1
# HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse: 1
# HKCharacteristicTypeIdentifierDateOfBirth: 1
# HKCharacteristicTypeIdentifierFitzpatrickSkinType: 1
# activeEnergyBurned: 961
# activeEnergyBurnedGoal: 961
# activeEnergyBurnedUnit: 961
# appleExerciseTime: 961
# appleExerciseTimeGoal: 961
# appleMoveTime: 961
# appleMoveTimeGoal: 961
# appleStandHours: 961
# appleStandHoursGoal: 961
# creationDate: 2378351
# dateComponents: 961
# device: 2346928
# duration: 128
# durationUnit: 128
# endDate: 2378351
# sourceName: 2378351
# sourceVersion: 2371021
# startDate: 2378351
# type: 2378223
# unit: 2364904
# value: 2378178
# workoutActivityType: 128
#
# Record types:
# ActiveEnergyBurned: 751195
# ...
