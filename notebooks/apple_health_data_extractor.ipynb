# %%
# this command takes forever and will spit out many duplicate 'startDate' errors to be handled MANUALLY
# only run it when you have a fresh export.xml to parse

# %run -i '../scripts/extract_apple_health_data' '../observationsexport.xml'

# %%
import numpy as np
import pandas as pd
import glob

# %%
activity = pd.read_csv('../Workout.csv')

# %%
activity.tail()
# Out:
#              sourceName sourceVersion  \
# 123  John’s Apple Watch           9.0
# 124  John’s Apple Watch           9.0
# 125  John’s Apple Watch           9.0
# 126  John’s Apple Watch         9.0.2
# 127  John’s Apple Watch         9.0.2
#
#                                                 device  \
# 123  <<HKDevice: 0x2836f2b20>, name:Peloton, manufa...
# 124  <<HKDevice: 0x2836f2b20>, name:Peloton, manufa...
# 125  <<HKDevice: 0x2836f2b20>, name:Peloton, manufa...
# 126  <<HKDevice: 0x2836f2b20>, name:Peloton, manufa...
# 127  <<HKDevice: 0x2836f2b20>, name:Peloton, manufa...
#
#                   creationDate                  startDate  \
# 123  2022-10-12 19:39:48 -0400  2022-10-12 19:09:37 -0400
# 124  2022-10-15 11:21:06 -0400  2022-10-15 11:10:02 -0400
# 125  2022-10-15 11:54:48 -0400  2022-10-15 11:23:42 -0400
# 126  2022-10-22 08:38:27 -0400  2022-10-22 08:27:27 -0400
# 127  2022-10-22 09:11:27 -0400  2022-10-22 08:41:17 -0400
#
# ...

# %%
sleep = pd.read_csv('../SleepAnalysis.csv')

# %%
sleep.tail()
# Out:
#               sourceName sourceVersion  device           type  unit  \
# 2855  John’s Apple Watch         9.0.2     NaN  SleepAnalysis   NaN
# 2856  John’s Apple Watch         9.0.2     NaN  SleepAnalysis   NaN
# 2857  John’s Apple Watch         9.0.2     NaN  SleepAnalysis   NaN
# 2858       John’s iPhone          16.0     NaN  SleepAnalysis   NaN
# 2859       John’s iPhone          16.0     NaN  SleepAnalysis   NaN
#
#                    creationDate                  startDate  \
# 2855  2022-10-27 06:09:12 -0400  2022-10-27 05:21:15 -0400
# 2856  2022-10-27 06:09:12 -0400  2022-10-27 05:54:15 -0400
# 2857  2022-10-27 06:09:12 -0400  2022-10-27 05:56:15 -0400
# 2858  2022-10-27 06:09:10 -0400  2022-10-26 21:56:36 -0400
# 2859  2022-10-27 06:09:10 -0400  2022-10-27 06:03:17 -0400
#
#                         endDate                                   value
# 2855  2022-10-27 05:54:15 -0400  HKCategoryValueSleepAnalysisAsleepCore
# ...

# %%
sleep.info()

# %%
sleep.describe()
